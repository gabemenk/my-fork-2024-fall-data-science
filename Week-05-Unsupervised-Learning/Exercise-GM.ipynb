# %% [markdown]
# # Fall 2024 Data Science Track: Week 5 - Unsupervised Learning

# %% [markdown]
# ## Packages, Packages, Packages!
#
# Import *all* the things here! You need: `matplotlib`, `networkx`, `numpy`, and `pandas`―and also `ast.literal_eval` to correctly deserialize two columns in the `rules.tsv.xz` file.
#
# If you got more stuff you want to use, add them here too. 🙂

# %%
# Import stuff.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
from ast import literal_eval

# %% [markdown]
# # Instacart Association Rules

# %% [markdown]
# ## Introduction
#
# With the packages out of the way, now you will be working with the Instacart association rules data set, mined from the [Instacart Market Basket Analysis data set](https://www.kaggle.com/c/instacart-market-basket-analysis/data) on Kaggle. [The script](https://github.com/LiKenun/shopping-assistant/blob/main/api/preprocess_instacart_market_basket_analysis_data.py) that does it and the instructions to run it can be found in my [Shopping Assistant Project](https://github.com/LiKenun/shopping-assistant) repository.

# %% [markdown]
# ## Load the Data
#
# This code has already been pre-written, simply because there are a few quirks which require converters to ensure the correct deserialization of some columns.

# %%
rules_data_path = 'data/rules.tsv.xz'

df_rules = pd.read_csv(rules_data_path,
                       sep='\t',
                       quoting=3,
                       converters={
                           'consequent_item': literal_eval,
                           'antecedent_items': literal_eval
                       },
                       low_memory=True)

# %% [markdown]
# But just *how* many rules were just loaded‽

# %%
# Show the list of column names and the number of rules.
print('Column names:' , df_rules.columns) # column names
print('Number of rules: ' , len(df_rules))
# Out:
# Column names: Index(['consequent_item', 'transaction_count', 'item_set_count',
#        'antecedent_count', 'consequent_count', 'antecedent_items'],
#       dtype='object')
# Number of rules:  1048575

# %% [markdown]
# ## Metrics
#
# Compute the support, confidence, and lift of each rule.
#
# * The rule’s *support* tells you how frequently the set of items appears in the dataset. It’s important to prune infrequent sets from further consideration.
#     * The simple definition: $$P(A \cap B)$$
#     * `= item_set_count / transaction_count`
# * The rule’s *confidence* tells you how often a the rule is true. Divide the support for the set of items by the support for just the antecedents. Rules which are not true very often are also pruned.
#     * The simple definition: $$\frac{P(A \cap B)}{P(A)}$$
#     * `= item_set_count / transaction_count / (antecedent_count / transaction_count)`
#     * `= item_set_count / antecedent_count`
# * The rule’s *lift* tells you how much more likely the consequent is, given the antecedents, compared to its baseline probability. Divide the support for the set of items by both the support of the antecedents and consequent. Equivalently, divide the confidence by the support of the consequent.
#     * The simple definition: $$\frac{P(A \cap B)}{P(A) \cdot P(B)}$$
#     * `= item_set_count / transaction_count / (antecedent_count / transaction_count * (consequent_count / transaction_count))`
#     * `= item_set_count / antecedent_count / (consequent_count / transaction_count)`
#     * `= item_set_count * transaction_count / (antecedent_count * consequent_count)`

# %%
# Add new columns support, confidence, and lift to df_rules. And show the first 50 rules.

df_rules['support'] = df_rules['item_set_count'] / df_rules['transaction_count']
df_rules['lift'] = df_rules['item_set_count'] / df_rules['antecedent_count'] / (df_rules['consequent_count'] / df_rules['transaction_count'])
df_rules['confidence'] = df_rules['item_set_count'] * df_rules['transaction_count'] / (df_rules['antecedent_count'] * df_rules['consequent_count'])
df_rules.head(50)
# Out:
#                                       consequent_item  transaction_count  \
# 0   Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 1   Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 2    Total 0% with Honey Nonfat Greek Strained Yogurt            3346083
# 3                           Total 0% Raspberry Yogurt            3346083
# 4                                 Pineapple Yogurt 2%            3346083
# 5                          Fat Free Strawberry Yogurt            3346083
# 6                           Fat Free Blueberry Yogurt            3346083
# 7   Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 8   Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 9   Total 2% Greek Strained Yogurt with Cherry 5.3 oz            3346083
# 10  Total 2% All Natural Greek Strained Yogurt wit...            3346083
# 11                          Total 0% Raspberry Yogurt            3346083
# 12                                Pineapple Yogurt 2%            3346083
# 13                         Fat Free Strawberry Yogurt            3346083
# 14                                  Blackberry Yogurt            3346083
# 15  Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 16  Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 17   Total 0% with Honey Nonfat Greek Strained Yogurt            3346083
# 18                          Total 0% Raspberry Yogurt            3346083
# 19                                Pineapple Yogurt 2%            3346083
# 20                         Fat Free Strawberry Yogurt            3346083
# 21                          Fat Free Blueberry Yogurt            3346083
# 22  Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 23  Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 24  Total 2% Greek Strained Yogurt with Cherry 5.3 oz            3346083
# 25  Total 2% All Natural Greek Strained Yogurt wit...            3346083
# 26                          Total 0% Raspberry Yogurt            3346083
# 27                                Pineapple Yogurt 2%            3346083
# 28                         Fat Free Strawberry Yogurt            3346083
# 29                                  Blackberry Yogurt            3346083
# 30  Total 2% with Strawberry Lowfat Greek Strained...            3346083
# 31  Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 32   Total 2% Lowfat Greek Strained Yogurt with Peach            3346083
# 33  Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 34  Total 2% Greek Strained Yogurt with Cherry 5.3 oz            3346083
# 35  Total 2% All Natural Greek Strained Yogurt wit...            3346083
# 36                          Total 0% Raspberry Yogurt            3346083
# 37                         Fat Free Strawberry Yogurt            3346083
# 38                                  Blackberry Yogurt            3346083
# 39  Total 2% with Strawberry Lowfat Greek Strained...            3346083
# 40  Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 41   Total 2% Lowfat Greek Strained Yogurt with Peach            3346083
# 42  Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 43  Total 2% Greek Strained Yogurt with Cherry 5.3 oz            3346083
# 44  Total 2% All Natural Greek Strained Yogurt wit...            3346083
# 45                          Total 0% Raspberry Yogurt            3346083
# 46                         Fat Free Strawberry Yogurt            3346083
# 47                                  Blackberry Yogurt            3346083
# 48  Total 2% with Raspberry Pomegranate Lowfat Gre...            3346083
# 49  Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
#
#     item_set_count  antecedent_count  consequent_count  \
# 0              101               123               128
# 1              101               128               123
# 2              101               123               128
# 3              101               123               128
# 4              101               128               123
# 5              101               123               128
# 6              101               128               123
# 7              101               147               117
# 8              101               147               117
# 9              101               117               147
# 10             101               117               147
# 11             101               147               117
# 12             101               147               117
# 13             101               117               147
# 14             101               117               147
# 15             101               119               145
# 16             101               145               119
# 17             101               119               145
# 18             101               145               119
# 19             101               145               119
# 20             101               119               145
# 21             101               145               119
# 22             101               132               133
# 23             101               132               133
# 24             101               133               132
# 25             101               132               133
# 26             101               133               132
# 27             101               133               132
# 28             101               132               133
# 29             101               133               132
# 30             103               129               139
# 31             103               139               129
# 32             103               139               129
# 33             103               139               129
# 34             103               129               139
# 35             103               139               129
# 36             103               139               129
# 37             103               129               139
# 38             103               129               139
# 39             103               144               125
# 40             103               144               125
# 41             103               125               144
# 42             103               144               125
# 43             103               125               144
# 44             103               144               125
# 45             103               144               125
# 46             103               125               144
# 47             103               125               144
# 48             102               123               145
# 49             102               145               123
#
#                                      antecedent_items   support          lift  \
# 0   [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030  21465.598514
# 1   [Fat Free Strawberry Yogurt, Total 0% Raspberr...  0.000030  21465.598514
# 2   [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030  21465.598514
# 3   [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030  21465.598514
# 4   [Fat Free Strawberry Yogurt, Total 0% Raspberr...  0.000030  21465.598514
# 5   [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030  21465.598514
# 6   [Fat Free Strawberry Yogurt, Total 0% Raspberr...  0.000030  21465.598514
# 7   [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000030  19649.653061
# 8   [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000030  19649.653061
# 9   [Pineapple Yogurt 2%, Total 0% Raspberry Yogur...  0.000030  19649.653061
# 10  [Pineapple Yogurt 2%, Total 0% Raspberry Yogur...  0.000030  19649.653061
# 11  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000030  19649.653061
# 12  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000030  19649.653061
# 13  [Pineapple Yogurt 2%, Total 0% Raspberry Yogur...  0.000030  19649.653061
# 14  [Pineapple Yogurt 2%, Total 0% Raspberry Yogur...  0.000030  19649.653061
# 15  [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030  19585.881368
# 16  [Fat Free Strawberry Yogurt, Total 0% with Hon...  0.000030  19585.881368
# 17  [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030  19585.881368
# 18  [Fat Free Strawberry Yogurt, Total 0% with Hon...  0.000030  19585.881368
# 19  [Fat Free Strawberry Yogurt, Total 0% with Hon...  0.000030  19585.881368
# 20  [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030  19585.881368
# 21  [Fat Free Strawberry Yogurt, Total 0% with Hon...  0.000030  19585.881368
# 22  [Blackberry Yogurt, Pineapple Yogurt 2%, Total...  0.000030  19250.078776
# 23  [Blackberry Yogurt, Pineapple Yogurt 2%, Total...  0.000030  19250.078776
# 24  [Fat Free Strawberry Yogurt, Total 2% All Natu...  0.000030  19250.078776
# 25  [Blackberry Yogurt, Pineapple Yogurt 2%, Total...  0.000030  19250.078776
# 26  [Fat Free Strawberry Yogurt, Total 2% All Natu...  0.000030  19250.078776
# 27  [Fat Free Strawberry Yogurt, Total 2% All Natu...  0.000030  19250.078776
# 28  [Blackberry Yogurt, Pineapple Yogurt 2%, Total...  0.000030  19250.078776
# 29  [Fat Free Strawberry Yogurt, Total 2% All Natu...  0.000030  19250.078776
# 30  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031  19220.709888
# 31  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031  19220.709888
# 32  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031  19220.709888
# 33  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031  19220.709888
# 34  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031  19220.709888
# 35  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031  19220.709888
# 36  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031  19220.709888
# 37  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031  19220.709888
# 38  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031  19220.709888
# 39  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031  19147.030500
# 40  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031  19147.030500
# 41  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031  19147.030500
# 42  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031  19147.030500
# 43  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031  19147.030500
# 44  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031  19147.030500
# 45  [Blackberry Yogurt, Fat Free Strawberry Yogurt...  0.000031  19147.030500
# 46  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031  19147.030500
# 47  [Total 0% Raspberry Yogurt, Total 2% All Natur...  0.000031  19147.030500
# 48  [Fat Free Blueberry Yogurt, Pineapple Yogurt 2...  0.000030  19136.555425
# 49  [Fat Free Strawberry Yogurt, Total 0% with Hon...  0.000030  19136.555425
#
#       confidence
# 0   21465.598514
# 1   21465.598514
# 2   21465.598514
# 3   21465.598514
# 4   21465.598514
# 5   21465.598514
# 6   21465.598514
# 7   19649.653061
# 8   19649.653061
# 9   19649.653061
# 10  19649.653061
# 11  19649.653061
# 12  19649.653061
# 13  19649.653061
# 14  19649.653061
# 15  19585.881368
# 16  19585.881368
# 17  19585.881368
# 18  19585.881368
# 19  19585.881368
# 20  19585.881368
# 21  19585.881368
# 22  19250.078776
# 23  19250.078776
# 24  19250.078776
# 25  19250.078776
# 26  19250.078776
# 27  19250.078776
# 28  19250.078776
# 29  19250.078776
# 30  19220.709888
# 31  19220.709888
# 32  19220.709888
# 33  19220.709888
# 34  19220.709888
# 35  19220.709888
# 36  19220.709888
# 37  19220.709888
# 38  19220.709888
# 39  19147.030500
# 40  19147.030500
# 41  19147.030500
# 42  19147.030500
# 43  19147.030500
# 44  19147.030500
# 45  19147.030500
# 46  19147.030500
# 47  19147.030500
# 48  19136.555425
# 49  19136.555425

# %% [markdown]
# The yogurts have got some insane lift (*over 9,000*). Why do you think that might be?

# %% [markdown]
# *(Write your answer here.)*

# %%
# Query the rule set if you have to to find out more.
# Lift in this case is just how much more likely someone is to buy one yogurt because they bought another.
# In my experience, yogurts are really small, cheap, and come in many different flavors, so I'm almost never buying just one. It's almost always a few different ones all at once.

# %% [markdown]
# ## Network Visualization for Consequents with Single Antecedents
#
# Let’s now visualize a small subset of 1,000,000+ rules. First, filter the rule set for the following to whittle it down to something more manageable:
#
# 1. The rule must have exactly `1` antecedent item. (There should be 38,684 such rules.)
# 2. The lift must be between `5` and `20`. (There should be 1,596 such rules, including the prior criterion.)
# 3. Either the antecedent or consequent of the rule must contain `'Hummus'`, but not both. (This should get you down to 26 rules.)
#     * Convert the antecedents `list`-typed column to a `str`-typed column (`antecedent_item`) since there will only be a single antecedent in the subset.
#     * Replace any item containing `'Hummus'` to just `'Hummus'`. This will make the visualization more readable later.
#
# Hint: your code may run more efficiently if you re-order certain processing steps.
#
# Assign the subset to `df_rules_subset`.

# %%
#pt 1
def select_greater_one(input_list):
    if len(input_list) == 1:
        return True
    else:
        return False
df_rules_subset = df_rules[df_rules['antecedent_items'].apply(select_greater_one)]

#pt 2
select_greater_5 = df_rules_subset['lift'] > 5
select_less_20 = df_rules_subset['lift'] < 20
df_rules_subset = df_rules_subset[select_greater_5 & select_less_20]

#pt 3
def hummus_is_in(input_str):
    if 'Hummus' in input_str:
        return True
    else:
        return False

def replace_hummus(input_str):
    if 'Hummus' in input_str:
        return 'Hummus'
    else:
        return input_str

def list_to_string(input_list):
    return input_list[0]

df_rules_subset['antecedent_item'] = df_rules_subset['antecedent_items'].apply(list_to_string)

select_hummus_ante = df_rules_subset['antecedent_item'].apply(hummus_is_in)
select_hummus_conse = df_rules_subset['consequent_item'].apply(hummus_is_in)

df_rules_subset = df_rules_subset[select_hummus_ante ^ select_hummus_conse]

df_rules_subset['antecedent_item'] = df_rules_subset['antecedent_item'].apply(replace_hummus)
df_rules_subset['consequent_item'] = df_rules_subset['consequent_item'].apply(replace_hummus)

df_rules_subset.head(20)
# Out:
#                                           consequent_item  transaction_count  \
# 377756  Total 2% Lowfat Greek Strained Yogurt With Blu...            3346083
# 387837                                        Clementines            3346083
# 416420                                             Hummus            3346083
# 419119                                             Hummus            3346083
# 422178                                             Hummus            3346083
# 440198                                             Hummus            3346083
# 442099                               Organic Baby Carrots            3346083
# 463035                                             Hummus            3346083
# 463988                                             Hummus            3346083
# 476420                                             Hummus            3346083
# 506520                                             Hummus            3346083
# 519416                                             Hummus            3346083
# 523791                                             Hummus            3346083
# 531448                                             Hummus            3346083
# 546619                                             Hummus            3346083
# 547477                                             Hummus            3346083
# 550256                               Organic Baby Carrots            3346083
# 554787                                             Hummus            3346083
# 567246                                             Hummus            3346083
# 570788                         Organic Small Bunch Celery            3346083
#
#         item_set_count  antecedent_count  consequent_count  \
# 377756             100               887             21405
# 387837             174              1334             32194
# 416420             345              1656             74172
# 419119             293              1434             74172
# 422178             331              1655             74172
# 440198            3119             17333             74172
# 442099             258              1334             80493
# 463035             151               933             74172
# 463988             311              1929             74172
# 476420             512              3333             74172
# 506520             168              1208             74172
# 519416             117               875             74172
# 523791            1544             11702             74172
# 531448             166              1287             74172
# 546619             244              1973             74172
# 547477             104               843             74172
# 550256             122               918             80493
# 554787             250              2066             74172
# 567246             221              1887             74172
# 570788             109               985             70714
#
#                                          antecedent_items   support  \
# 377756             [Roasted Red Pepper Hummus With Chips]  0.000030
# 387837                           [Organic Classic Hummus]  0.000052
# 416420                         [Organic White Pita Bread]  0.000103
# 419119                         [Organic Whole Wheat Pita]  0.000088
# 422178                      [Mini Whole Wheat Pita Bread]  0.000099
# 440198                              [Sea Salt Pita Chips]  0.000932
# 442099                           [Organic Classic Hummus]  0.000077
# 463035                [Lentil Chips, Himalayan Pink Salt]  0.000045
# 463988                     [Garbanzo Beans No Salt Added]  0.000093
# 476420                [Organic Whole Peeled Baby Carrots]  0.000153
# 506520                      [Baba Ghannouge Eggplant Dip]  0.000050
# 519416  [Sonoma Organic Wraps Multigrain Tortillas Wit...  0.000035
# 523791                          [Pita Chips Simply Naked]  0.000461
# 531448                          [Honey Whole Wheat Bread]  0.000050
# 546619                                       [White Pita]  0.000073
# 547477                              [Organic Wraps Wheat]  0.000031
# 550256                                  [Kalamata Hummus]  0.000036
# 554787             [Rice Thins Brown Rice Snack Crackers]  0.000075
# 567246                                           [Dolmas]  0.000066
# 570788                            [Organic Garlic Hummus]  0.000033
#
#              lift  confidence  \
# 377756  17.623731   17.623731
# 387837  13.556738   13.556738
# 416420   9.398434    9.398434
# 419119   9.217543    9.217543
# 422178   9.022496    9.022496
# 440198   8.117800    8.117800
# 442099   8.039749    8.039749
# 463035   7.301163    7.301163
# 463988   7.273189    7.273189
# 476420   6.929970    6.929970
# 506520   6.273921    6.273921
# 519416   6.032183    6.032183
# 523791   5.952288    5.952288
# 531448   5.818704    5.818704
# 546619   5.579040    5.579040
# 547477   5.565478    5.565478
# 550256   5.524535    5.524535
# 554787   5.458916    5.458916
# 567246   5.283444    5.283444
# 570788   5.236264    5.236264
#
#                                           antecedent_item
# 377756                                             Hummus
# 387837                                             Hummus
# 416420                           Organic White Pita Bread
# 419119                           Organic Whole Wheat Pita
# 422178                        Mini Whole Wheat Pita Bread
# 440198                                Sea Salt Pita Chips
# 442099                                             Hummus
# 463035                  Lentil Chips, Himalayan Pink Salt
# 463988                       Garbanzo Beans No Salt Added
# 476420                  Organic Whole Peeled Baby Carrots
# 506520                        Baba Ghannouge Eggplant Dip
# 519416  Sonoma Organic Wraps Multigrain Tortillas With...
# 523791                            Pita Chips Simply Naked
# 531448                            Honey Whole Wheat Bread
# 546619                                         White Pita
# 547477                                Organic Wraps Wheat
# 550256                                             Hummus
# 554787               Rice Thins Brown Rice Snack Crackers
# 567246                                             Dolmas
# 570788                                             Hummus

# %% [markdown]
# Build a network `graph_rules_subset` from the association rules subset.

# %%
# Define graph_rules_subset, add the graph’s edges, and plot it. You may need a large figure size, smaller node size, and smaller font size.

graph_rules_subset = nx.MultiDiGraph()
edges = [(row['antecedent_item'], row['consequent_item']) for _, row in df_rules_subset.iterrows()]

graph_rules_subset.add_edges_from(edges)
plt.figure(figsize=(15, 10))  # large figure size
pos = nx.spring_layout(graph_rules_subset) # position for nodes
# Then render the graph.
nx.draw(graph_rules_subset, pos, with_labels=True, node_size=200, font_size=6, arrows=True)
plt.title("Rules Subset Graph")
plt.show()

# %% [markdown]
# What can you tell about people who buy hummus?

# %% [markdown]
# I can tell that there's certain foods they're relatively likely to get in addition to the hummus, and vice versa, with some of those
# less likely foods being clementines and baby carrots. Some of the more likely addittions are common food for dipping into hummus like pita chips
#  and other dips like eggplant dip.

# %% [markdown]
# ## Make a Prediction
#
# Given that the basket of items contains the following items, use the full set of association rules to predict the next 20 most likely items (consequents) that the person will add to the basket in descending order of lift:
#
# * `'Orange Bell Pepper'`
# * `'Organic Red Bell Pepper'`
#
# Hint: a single item in the basket may be a better predictor of some consequents than both items considered together. You must consider both or either, but not neither.

# %%
basket = {'Orange Bell Pepper', 'Organic Red Bell Pepper'}

df_rules[df_rules['antecedent_items'].apply(lambda x: any(item in x for item in basket))] \
        .sort_values('lift', ascending=False) \
        .head(20)
# Out:
#                                           consequent_item  transaction_count  \
# 342462      Icelandic Style Skyr Blueberry Non-fat Yogurt            3346083
# 345882      Icelandic Style Skyr Blueberry Non-fat Yogurt            3346083
# 346832           Nonfat Icelandic Style Strawberry Yogurt            3346083
# 346901                           Non Fat Raspberry Yogurt            3346083
# 349532      Icelandic Style Skyr Blueberry Non-fat Yogurt            3346083
# 350852      Icelandic Style Skyr Blueberry Non-fat Yogurt            3346083
# 350991                           Non Fat Raspberry Yogurt            3346083
# 351360      Icelandic Style Skyr Blueberry Non-fat Yogurt            3346083
# 351433           Nonfat Icelandic Style Strawberry Yogurt            3346083
# 351881      Icelandic Style Skyr Blueberry Non-fat Yogurt            3346083
# 352283                         Vanilla Skyr Nonfat Yogurt            3346083
# 352884                        Organic Frozen Mango Chunks            3346083
# 353323                         Vanilla Skyr Nonfat Yogurt            3346083
# 353543                         Organic Orange Bell Pepper            3346083
# 353580                           Non Fat Raspberry Yogurt            3346083
# 353760                             Organic Sliced Peaches            3346083
# 354421  Total 2% with Strawberry Lowfat Greek Strained...            3346083
# 355427                                Organic Bell Pepper            3346083
# 355819                                Organic Bell Pepper            3346083
# 356261                                 Yellow Bell Pepper            3346083
#
#         item_set_count  antecedent_count  consequent_count  \
# 342462             100               209             19962
# 345882             132               311             19962
# 346832             100               441             11025
# 346901             184               529             16953
# 349532             184               494             19962
# 350852             167               471             19962
# 350991             132               441             16953
# 351360             101               291             19962
# 351433             101               529             11025
# 351881             133               392             19962
# 352283             167               529             18899
# 352884             109               612             10938
# 353323             133               441             18899
# 353543             145               834             11005
# 353580             126               471             16953
# 353760             109               676             10300
# 354421             235               502             30866
# 355427             114               324             24331
# 355819             145               420             24331
# 356261             109               295             26625
#
#                                          antecedent_items   support  \
# 342462  [Nonfat Icelandic Style Strawberry Yogurt, Ora...  0.000030
# 345882     [Non Fat Raspberry Yogurt, Orange Bell Pepper]  0.000039
# 346832  [Icelandic Style Skyr Blueberry Non-fat Yogurt...  0.000030
# 346901  [Icelandic Style Skyr Blueberry Non-fat Yogurt...  0.000055
# 349532  [Non Fat Raspberry Yogurt, Organic Red Bell Pe...  0.000055
# 350852  [Organic Red Bell Pepper, Vanilla Skyr Nonfat ...  0.000050
# 350991  [Icelandic Style Skyr Blueberry Non-fat Yogurt...  0.000039
# 351360  [Nonfat Icelandic Style Strawberry Yogurt, Org...  0.000030
# 351433  [Icelandic Style Skyr Blueberry Non-fat Yogurt...  0.000030
# 351881   [Orange Bell Pepper, Vanilla Skyr Nonfat Yogurt]  0.000040
# 352283  [Icelandic Style Skyr Blueberry Non-fat Yogurt...  0.000050
# 352884  [Organic Red Bell Pepper, Organic Sliced Peaches]  0.000033
# 353323  [Icelandic Style Skyr Blueberry Non-fat Yogurt...  0.000040
# 353543  [Organic Bell Pepper, Organic Raspberries, Org...  0.000043
# 353580  [Organic Red Bell Pepper, Vanilla Skyr Nonfat ...  0.000038
# 353760  [Organic Frozen Mango Chunks, Organic Red Bell...  0.000033
# 354421  [Organic Red Bell Pepper, Total 2% Lowfat Gree...  0.000070
# 355427  [Organic Cucumber, Organic Orange Bell Pepper,...  0.000034
# 355819  [Organic Orange Bell Pepper, Organic Raspberri...  0.000043
# 356261     [Grade A Large Brown Eggs, Orange Bell Pepper]  0.000033
#
#              lift  confidence
# 342462  80.202217   80.202217
# 345882  71.145298   71.145298
# 346832  68.820769   68.820769
# 346901  68.651858   68.651858
# 349532  62.434341   62.434341
# 350852  59.433078   59.433078
# 350991  59.077960   59.077960
# 351360  58.178302   58.178302
# 351433  57.946047   57.946047
# 351881  56.871965   56.871965
# 352283  55.893163   55.893163
# 352884  54.484612   54.484612
# 353323  53.396272   53.396272
# 353543  52.862612   52.862612
# 353580  52.800713   52.800713
# 353760  52.381664   52.381664
# 354421  50.748184   50.748184
# 355427  48.387880   48.387880
# 355819  47.478333   47.478333
# 356261  46.435655   46.435655

# %% [markdown]
# ## Bonus: Other Interesting Findings
#
# Find and share something else interesting about these association rules. It can be a graph, table, or some other format that illustrates your point.
